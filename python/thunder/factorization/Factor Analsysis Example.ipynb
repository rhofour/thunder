# %% [markdown]
# # Factor Analysis Example

# %% [markdown]
# ## Load Stuff

# %%
from thunder import PCA
from numpy import array, linspace, newaxis

# %% [markdown]
# ## Setup Plotting

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
sns.set_context('notebook')
sns.set_style('darkgrid')

# %% [markdown]
# ## Generate example data

# %%
sigmas = array([0.01, 0.01, 0.1])
x = tsc.makeExample('fa', sigmas=sigmas)

# %%
x.first()
# Out:
# ((37, 24, 15), array([-3.732075  ,  0.39857996,  0.59029281]))

# %%
localX = x.collectValuesAsArray()

# %% [markdown]
# ### Graph Example Data

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(localX[:, 0], localX[:, 1], localX[:, 2])

# %% [markdown]
# ## Try PCA

# %%
pcaModel = PCA(k=1).fit(x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(localX[:, 0], localX[:, 1], localX[:, 2])

line = linspace(-10, 10)[:, newaxis] * pcaModel.comps
ax.plot(line[:,0], line[:,1], line[:,2], 'r')
